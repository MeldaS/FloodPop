# %%
import os, time
import country_converter as cc

import pandas as pd 
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import json
#import pprint
from pathlib import Path 
import pycountry 

import rasterio as rs
from rasterio.plot import show
from rasterio.enums import Resampling
from rasterio.plot import plotting_extent
from rasterio.merge import merge
import rasterio.mask

def tPrint(s):
    print("%s\t%s" % (time.strftime("%H:%M:%S"), s))

# %% [markdown]
# ### Add flowchart here as link

# %% [markdown]
# ## Country names
# * List of flood folder names to iterate through
# * Change the *countryIndex* in the below cell to test out different countries.
# * Currently the script uses *FloodCountryFoldersTemp* as the list of countries

# %%
# Select a country index from above to test different countries
countryIndex = 0

# %%
# The names of the folders under flood_path 
FloodCountryFolders = ['vietnam', 'Cameroon', 'Kenya', 'Ghana', 'Angola', 'Afghanistan', 'Azerbaijan', 'Armenia', 'Aruba', 'andorra', 'Antigua & Barbuda', 'Li', 'Chad', 'Cuba', 'Indonesia', 'Pakistan', 'Myanmar', 'Serbia', 'Montserrat', 'vatican', 'Anguilla', 'monaco', 'sanmarino', 'Grenada', 'Barbados', 'malta', 'Dominica', 'Martinique', 'Maldives', 'Seychelles', 'singapore', 'Comoros', 'Guadeloupe', 'Cape_Verde', 'Mauritius', 'luxembourg', 'Jamaica', 'Lebanon', 'cyprus', 'Djibouti', 'kosovo', 'Swaziland', 'montenegro', 'Brunei', 'Timor-Leste', 'Lesotho', 'Bhutan', 'kuwait', 'Gambia', 'rwanda', 'burundi', 'El_salvador', 'macedonia', 'cambodia', 'malawi', 'Bahamas', 'Botswana', 'croatia', 'bulgaria', 'bosnia', 'Benin', 'belarus', 'Belize', 'belgium', 'Nigeria', 'peru', 'Mongolia', 'latvia', 'denmark', 'Mali', 'ireland', 'Eritrea', 'Mozambique', 'estonia', 'slovenia', 'Mexico', 'tanzania', 'Nepal', 'Liberia', 'Nicaragua', 'Georgia', 'Haiti', 'Ethiopia', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'hungary', 'ukraine', 'Zambia', 'Thailand', 'sweden', 'turkey', 'Somalia', 'finland', 'Namibia', 'germany', 'norway', 'Iraq', 'Turkmenistan', 'Japan', 'Madagascar', 'spain', 'Philippines', 'Niger', 'Poland', 'uk', 'Malaysia', 'Mauritania', 'Romania', 'Zimbabwe', 'Senegal', 'laos', 'greece', 'Uganda', 'Syria', 'Yemen', 'Kyrgyzstan', 'lithuania', 'Tajikistan', 'sierraleone', 'portugal', 'Togo', 'Taiwan', 'moldova', 'Jordan', 'albania']

# %%
# Using this as temporarily as these are the files I have access to
FloodCountryFoldersTemp = ['vietnam', 'tanzania', 'Ethiopia']

# %% [markdown]
# ## Defining paths
# *Change the path in the first cell to the GLOBAL folder containing file contents.*
# *Change the path in the second cell to the a location where a few folders can be created to save outputs.*

# %%
path = Path('/home/public/Data/GLOBAL') #Change Path

# %%
outputPath = Path('/home/wb411133/data/Projects/FATHOM') #Change Path

# %% [markdown]
# *Here we define all the folder names and combine them using Pathlib to ensure compatibility between different operating systems.*

# %%
# World Admin
worldAdmin_Folder = 'GMGD world admin'
admin_File = 'GMGD18.shp' 

# Flood files (non-coastal)
flood_Folder = 'FLOOD_SSBN'
flood_subFolder = 'v2_2019'
fluvialFlood_Folder = 'fluvial_undefended'
fluvialFlood_FileName = 'FU_1in100.tif' 
pluvialFlood_Folder = 'pluvial'
pluvialFlood_FileName = 'P_1in100.tif' 

# Coastal flood files
coastalFlood_Folder = 'Coastal_flood'
coastalFlood_File = "ss_muis_rp0100m.tif"

# Population data
pop_Folder = 'Population'
pop_subFolder = 'WorldPop_PPP_2020'
pop_subsubFolder = 'MOSAIC_ppp_prj_2020'

# Folder paths
flood_path = path / flood_Folder / flood_subFolder 
population_path = path / pop_Folder / pop_subFolder / pop_subsubFolder 

# Global files paths
adm_path = path / worldAdmin_Folder / admin_File
coastalFlood_path = path / coastalFlood_Folder / coastalFlood_File
 
print(flood_path)
print(population_path)
print(adm_path)
print(coastalFlood_path)
# Out:
# /home/public/Data/GLOBAL/FLOOD_SSBN/v2_2019
# /home/public/Data/GLOBAL/Population/WorldPop_PPP_2020/MOSAIC_ppp_prj_2020
# /home/public/Data/GLOBAL/GMGD world admin/GMGD18.shp
# /home/public/Data/GLOBAL/Coastal_flood/ss_muis_rp0100m.tif

# %% [markdown]
# ## Creating folders for intermediate & final outputs

# %%
# Creating folder for all outputs
output_Folder = 'Outputs'
output_FolderPath = outputPath / output_Folder
try: 
    output_FolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for raster outputs
Raster_outputFolder = 'FloodPop_Countries'
Raster_outputFolderPath = output_FolderPath / Raster_outputFolder
try: 
    Raster_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for coastal flood country files
cFlood_outputFolder = 'CoastalFlood_Countries'
cFlood_outputFolderPath = output_FolderPath / cFlood_outputFolder
try: 
    cFlood_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for aggregated flood country files (fluvial + pluvial + coastal)
Flood_outputFolder = 'Flood_Countries'
Flood_outputFolderPath = output_FolderPath / Flood_outputFolder
try: 
    Flood_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %% [markdown]
# ## Flood Bins

# %%
# Define flood bins:
## 0) No risk: x = 0
## 1) Limited risk: x <= 0.15
## 2) Moderate risk: 0.15 < x <= 0.5
## 3) High risk: 0.5 < x <= 1.5
## 4) Very high risk: x > 1.5
## 5) Water body: x >= 999

flood_bins = [1e-10,0.15,0.5,1.5,998,10000] 
# Use right=True when digitizing to include right bin edge
# Note: 0 contains flood depths of 0 up to 0.0000000001 -> no flood

numberCategories = len(flood_bins)

# %% [markdown]
# ## Supporting functions

# %%
# Function to calculate summary stats for arrays
def stats (array): 
    stats_dict={
   'min': array.min(),
   'mean': array.mean(),
   'median': np.median(array),
   'max': array.max()}
    return stats_dict

# %% [markdown]
# ## Results dataframe

# %%
# An empty dataframe to store the results of each loop
result = pd.DataFrame(columns = ['OBJECTID',
                                '0 - NoRiskPop',
                                '1 - LowRiskPop', 
                                '2 - ModerateRiskPop', 
                                '3 - HighRiskPop', 
                                '4 - VeryHighRiskPop', 
                                '5 - WaterBodyPop',
                                'ISO3']).set_index('OBJECTID')

# %% [markdown]
# ## Admin shapefiles

# %%
# Read shapefile
adm = gpd.read_file(adm_path)
adm = adm[['OBJECTID','ADM0_NAME','ADM1_NAME','CountryCod','geometry']]

# Removing first row which is the "Sovereign Base Areas of Akrotiri and Dhekelia"
# It doesn't match other country files
adm = adm.iloc[1:] 

# Converting dtype to int16 to reduce memory usage
adm[['OBJECTID']] = adm[['OBJECTID']].astype('int16') 

# Setting OBJECTID as index
adm = adm.set_index('OBJECTID')

# %% [markdown]
# # Main loop

# %%
list2019 = [os.path.basename(str(x)) for x in flood_path.iterdir() if x.is_dir()]

countriesDF = adm[['ADM0_NAME','CountryCod']]
countriesDF = countriesDF.drop_duplicates(subset ="ADM0_NAME")
# Sort alphabetically
countriesDF.sort_values(by=['ADM0_NAME']);

# Put col values in list for easier comparison
admList = countriesDF.ADM0_NAME.values.tolist()
admList.sort()
matching_dict = cc.match(admList, list2019)
# Out:
# WARNING:root:Could not find any correspondence for Algeria in list_b
# WARNING:root:Could not find any correspondence for American Samoa (U.S.) in list_b
# WARNING:root:Could not find any correspondence for Arab Republic of Egypt in list_b
# WARNING:root:Could not find any correspondence for Argentina in list_b
# WARNING:root:Could not find any correspondence for Australia in list_b
# WARNING:root:Could not find any correspondence for Austria in list_b
# WARNING:root:Could not find any correspondence for Bahrain in list_b
# WARNING:root:Could not find any correspondence for Bangladesh in list_b
# WARNING:root:Could not find any correspondence for Bermuda (U.K.) in list_b
# WARNING:root:Could not find any correspondence for Brazil in list_b
# WARNING:root:Could not find any correspondence for Canada in list_b
# WARNING:root:Could not find any correspondence for Cape Verde in list_b
# WARNING:root:Could not find any correspondence for Chile in list_b
# WARNING:root:Could not find any correspondence for China in list_b
# WARNING:root:Could not find any correspondence for Curaçao (Neth.) in list_b
# WARNING:root:Could not find any correspondence for Czech Republic in list_b
# WARNING:root:Could not find any correspondence for Côte d'Ivoire in list_b
# WARNING:root:Could not find any correspondence for D. P. R. of Korea in list_b
# WARNING:root:Could not find any correspondence for Ecuador in list_b
# WARNING:root:Could not find any correspondence for Equatorial Guinea in list_b
# WARNING:root:Could not find any correspondence for Faroe Islands (Den.) in list_b
# WARNING:root:Multiple matches for name Fiji in list_b
# WARNING:root:Could not find any correspondence for France in list_b
# WARNING:root:Could not find any correspondence for Greenland (Den.) in list_b
# WARNING:root:Could not find any correspondence for Guam (U.S.) in list_b
# WARNING:root:Could not find any correspondence for Honduras in list_b
# WARNING:root:Could not find any correspondence for Iceland in list_b
# WARNING:root:Could not find any correspondence for India in list_b
# WARNING:root:Could not find any correspondence for Islamic Republic of Iran in list_b
# WARNING:root:Could not find any correspondence for Isle of Man (U.K.) in list_b
# WARNING:root:Could not find any correspondence for Israel in list_b
# WARNING:root:Could not find any correspondence for Italy in list_b
# WARNING:root:Could not find any correspondence for Kiribati in list_b
# WARNING:root:Could not find any correspondence for Libya in list_b
# WARNING:root:Could not find any correspondence for Liechtenstein in list_b
# WARNING:root:Could not find any correspondence for Macau, SAR in list_b
# WARNING:root:Could not find any correspondence for Morocco in list_b
# WARNING:root:Could not find any correspondence for Netherlands in list_b
# WARNING:root:Could not find any correspondence for New Zealand in list_b
# WARNING:root:Could not find any correspondence for Northern Mariana Islands (U.S.) in list_b
# WARNING:root:Could not find any correspondence for Oman in list_b
# WARNING:root:Could not find any correspondence for Qatar in list_b
# WARNING:root:Could not find any correspondence for R. B. de Venezuela in list_b
# WARNING:root:Could not find any correspondence for Republic of Korea in list_b
# WARNING:root:Could not find any correspondence for Russian Federation in list_b
# WARNING:root:Could not find any correspondence for Saint Kitts and Nevis in list_b
# WARNING:root:Could not find any correspondence for Saint-Martin (Fr.) in list_b
# WARNING:root:Could not find any correspondence for Saudi Arabia in list_b
# WARNING:root:Multiple matches for name Sierra Leone in list_b
# WARNING:root:Could not find any correspondence for Sint Maarten (Neth.) in list_b
# WARNING:root:Could not find any correspondence for Slovak Republic in list_b
# WARNING:root:Could not find any correspondence for South Sudan in list_b
# WARNING:root:Could not find any correspondence for Sudan in list_b
# WARNING:root:Could not find any correspondence for Svalbard and Jan Mayen (Nor.) in list_b
# WARNING:root:Could not find any correspondence for Switzerland in list_b
# WARNING:root:Could not find any correspondence for São Tomé and Príncipe in list_b
# WARNING:root:Could not find any correspondence for Tunisia in list_b
# WARNING:root:Could not find any correspondence for United Arab Emirates in list_b
# WARNING:root:Could not find any correspondence for United States of America in list_b
# WARNING:root:Could not find any correspondence for Uruguay in list_b
# WARNING:root:Could not find any correspondence for Uzbekistan in list_b
# WARNING:root:Could not find any correspondence for West Bank and Gaza in list_b
# {'Afghanistan': 'Afghanistan',
#  'Albania': 'albania',
#  'Algeria': 'not_found',
#  'American Samoa (U.S.)': 'not_found',
#  'Andorra': 'andorra',
#  'Angola': 'Angola',
#  'Antigua and Barbuda': 'Antigua & Barbuda',
#  'Arab Republic of Egypt': 'not_found',
#  'Argentina': 'not_found',
#  'Armenia': 'Armenia',
#  'Aruba (Neth.)': 'Aruba',
#  'Australia': 'not_found',
#  'Austria': 'not_found',
#  'Azerbaijan': 'Azerbaijan',
#  'Bahrain': 'not_found',
#  'Bangladesh': 'not_found',
#  'Barbados': 'Barbados',
#  'Belarus': 'belarus',
#  'Belgium': 'belgium',
#  'Belize': 'Belize',
#  'Benin': 'Benin',
#  'Bermuda (U.K.)': 'not_found',
#  'Bhutan': 'Bhutan',
#  'Bolivia': 'Bolivia',
#  'Bosnia and Herzegovina': 'bosnia',
#  'Botswana': 'Botswana',
#  'Brazil': 'not_found',
#  'Brunei Darussalam': 'Brunei',
#  'Bulgaria': 'bulgaria',
#  'Burkina Faso': 'Burkina Faso',
#  'Burundi': 'burundi',
#  'Cambodia': 'cambodia',
#  'Cameroon': 'Cameroon',
#  'Canada': 'not_found',
#  'Cape Verde': 'not_found',
#  'Cayman Islands (U.K.)': 'Cayman Islands',
#  'Central African Republic': 'Central African Republic',
#  'Chad': 'Chad',
#  'Chile': 'not_found',
#  'China': 'not_found',
#  'Colombia': 'Colombia',
#  'Comoros': 'Comoros',
#  'Congo': 'Republic of Congo',
#  'Costa Rica': 'Costa Rica',
#  'Croatia': 'croatia',
#  'Cuba': 'Cuba',
#  'Curaçao (Neth.)': 'not_found',
#  'Cyprus': 'cyprus',
#  'Czech Republic': 'not_found',
#  "Côte d'Ivoire": 'not_found',
#  'D. P. R. of Korea': 'not_found',
#  'Democratic Republic of Congo': 'Democratic Republic of Congo',
#  'Denmark': 'denmark',
#  'Djibouti': 'Djibouti',
#  'Dominica': 'Dominica',
#  'Dominican Republic': 'Dominican Republic',
#  'Ecuador': 'not_found',
#  'El Salvador': 'El_salvador',
#  'Equatorial Guinea': 'not_found',
#  'Eritrea': 'Eritrea',
#  'Estonia': 'estonia',
#  'Ethiopia': 'Ethiopia',
#  'FYR of Macedonia': 'macedonia',
#  'Faroe Islands (Den.)': 'not_found',
#  'Federated States of Micronesia': 'Micronesia',
#  'Fiji': ['Fiji_east', 'Fiji_west'],
#  'Finland': 'finland',
#  'France': 'not_found',
#  'French Polynesia (Fr.)': 'French Polynesia',
#  'Gabon': 'Gabon',
#  'Georgia': 'Georgia',
#  'Germany': 'germany',
#  'Ghana': 'Ghana',
#  'Greece': 'greece',
#  'Greenland (Den.)': 'not_found',
#  'Grenada': 'Grenada',
#  'Guam (U.S.)': 'not_found',
#  'Guatemala': 'Guatemala',
#  'Guinea': 'Guinea',
#  'Guinea-Bissau': 'Guinea-Bissau',
#  'Guyana': 'Guyana',
#  'Haiti': 'Haiti',
#  'Honduras': 'not_found',
#  'Hong Kong, SAR': 'Hong Kong',
#  'Hungary': 'hungary',
#  'Iceland': 'not_found',
#  'India': 'not_found',
#  'Indonesia': 'Indonesia',
#  'Iraq': 'Iraq',
#  'Ireland': 'ireland',
#  'Islamic Republic of Iran': 'not_found',
#  'Isle of Man (U.K.)': 'not_found',
#  'Israel': 'not_found',
#  'Italy': 'not_found',
#  'Jamaica': 'Jamaica',
#  'Japan': 'Japan',
#  'Jordan': 'Jordan',
#  'Kazakhstan': 'Kazakhstan',
#  'Kenya': 'Kenya',
#  'Kiribati': 'not_found',
#  'Kosovo': 'kosovo',
#  'Kuwait': 'kuwait',
#  'Kyrgyz Republic': 'Kyrgyzstan',
#  "Lao People's Democratic Republic": 'laos',
#  'Latvia': 'latvia',
#  'Lebanon': 'Lebanon',
#  'Lesotho': 'Lesotho',
#  'Liberia': 'Liberia',
#  'Libya': 'not_found',
#  'Liechtenstein': 'not_found',
#  'Lithuania': 'lithuania',
#  'Luxembourg': 'luxembourg',
#  'Macau, SAR': 'not_found',
#  'Madagascar': 'Madagascar',
#  'Malawi': 'malawi',
#  'Malaysia': 'Malaysia',
#  'Maldives': 'Maldives',
#  'Mali': 'Mali',
#  'Malta': 'malta',
#  'Marshall Islands': 'Marshall Islands',
#  'Mauritania': 'Mauritania',
#  'Mauritius': 'Mauritius',
#  'Mexico': 'Mexico',
#  'Moldova': 'moldova',
#  'Monaco': 'monaco',
#  'Mongolia': 'Mongolia',
#  'Montenegro': 'montenegro',
#  'Morocco': 'not_found',
#  'Mozambique': 'Mozambique',
#  'Myanmar': 'Myanmar',
#  'Namibia': 'Namibia',
#  'Nepal': 'Nepal',
#  'Netherlands': 'not_found',
#  'New Caledonia (Fr.)': 'New Caledonia',
#  'New Zealand': 'not_found',
#  'Nicaragua': 'Nicaragua',
#  'Niger': 'Niger',
#  'Nigeria': 'Nigeria',
#  'Northern Mariana Islands (U.S.)': 'not_found',
#  'Norway': 'norway',
#  'Oman': 'not_found',
#  'Pakistan': 'Pakistan',
#  'Palau': 'Palau',
#  'Panama': 'Panama',
#  'Papua New Guinea': 'Papua New Guinea',
#  'Paraguay': 'Paraguay',
#  'Peru': 'peru',
#  'Philippines': 'Philippines',
#  'Poland': 'Poland',
#  'Portugal': 'portugal',
#  'Puerto Rico (U.S.)': 'Puerto Rico',
#  'Qatar': 'not_found',
#  'R. B. de Venezuela': 'not_found',
#  'Republic of Korea': 'not_found',
#  'Republic of Yemen': 'Yemen',
#  'Romania': 'Romania',
#  'Russian Federation': 'not_found',
#  'Rwanda': 'rwanda',
#  'Saint Kitts and Nevis': 'not_found',
#  'Saint Lucia': 'St Lucia',
#  'Saint Vincent and the Grenadines': 'St Vincent and the Grenadines',
#  'Saint-Martin (Fr.)': 'not_found',
#  'Samoa': 'Samoa',
#  'San Marino': 'sanmarino',
#  'Saudi Arabia': 'not_found',
#  'Senegal': 'Senegal',
#  'Serbia': 'Serbia',
#  'Seychelles': 'Seychelles',
#  'Sierra Leone': ['Sierra Leone', 'sierraleone'],
#  'Singapore': 'singapore',
#  'Sint Maarten (Neth.)': 'not_found',
#  'Slovak Republic': 'not_found',
#  'Slovenia': 'slovenia',
#  'Solomon Islands': 'Solomon Islands',
#  'Somalia': 'Somalia',
#  'South Africa': 'South Africa',
#  'South Sudan': 'not_found',
#  'Spain': 'spain',
#  'Sri Lanka': 'Sri Lanka',
#  'Sudan': 'not_found',
#  'Suriname': 'Suriname',
#  'Svalbard and Jan Mayen (Nor.)': 'not_found',
#  'Swaziland': 'Swaziland',
#  'Sweden': 'sweden',
#  'Switzerland': 'not_found',
#  'Syrian Arab Republic': 'Syria',
#  'São Tomé and Príncipe': 'not_found',
#  'Taiwan': 'Taiwan',
#  'Tajikistan': 'Tajikistan',
#  'Tanzania': 'tanzania',
#  'Thailand': 'Thailand',
#  'The Bahamas': 'Bahamas',
#  'The Gambia': 'Gambia',
#  'Timor-Leste': 'Timor-Leste',
#  'Togo': 'Togo',
#  'Tonga': 'Tonga',
#  'Trinidad and Tobago': 'Trinidad and Tobago',
#  'Tunisia': 'not_found',
#  'Turkey': 'turkey',
#  'Turkmenistan': 'Turkmenistan',
#  'Turks and Caicos Islands (U.K.)': 'Turks and Caicos Islands',
#  'Tuvalu': 'tuvalu',
#  'Uganda': 'Uganda',
#  'Ukraine': 'ukraine',
#  'United Arab Emirates': 'not_found',
#  'United Kingdom': 'uk',
#  'United States of America': 'not_found',
#  'Uruguay': 'not_found',
#  'Uzbekistan': 'not_found',
#  'Vanuatu': 'Vanuatu',
#  'Vietnam': 'vietnam',
#  'West Bank and Gaza': 'not_found',
#  'Zambia': 'Zambia',
#  'Zimbabwe': 'Zimbabwe'}

# %%
result
# Out:
#           0 - NoRiskPop  1 - LowRiskPop  2 - ModerateRiskPop  3 - HighRiskPop  \
# OBJECTID
# 1           10733428.00      2269149.00           1266649.88       1146195.75
# 1886         4369553.00      1074387.00            505692.94        332553.47
# 1887         8706124.00       711610.38           1083108.88       3004978.75
# 1888         7961898.00      1588237.62            795141.00        937957.12
# 1889         2931318.75      1387528.12           1328191.50       4475979.50
# 1890        12036475.00       739946.38            562682.31       1347685.25
# 464          1046078.50       116928.98             37952.16         20553.42
# 465           530143.12        79444.60             28575.88         13141.66
# 466           750063.06       125772.14             51365.71         26782.82
# 467          1027207.50       198866.39             53486.37         21337.35
# 468           430106.59        49097.92             17945.55          9337.93
# 469           499802.19        91637.59             24033.37         11597.34
# 470           970717.31       151498.00             48276.73         20865.71
# 471           507854.03       264094.00             67442.18         13223.87
# 472           688054.62        85739.93             33055.20         16590.82
# 473           845979.00       124637.34             28468.65         13639.40
# 474          1733789.12       470825.62            148100.44         46860.37
# 475           315211.97       118626.23             52227.84         31732.14
# 476          3978069.75       497608.16            178144.09        111958.98
# 477          1246689.88       134301.94             26888.37          9446.03
# 478           365843.47        65528.87             24551.96         12901.88
# 479           823864.50         8036.94              3282.07          1288.60
# 480           499358.50        10851.39              4538.86          2321.08
# 481           588411.00       190567.11             71102.99         33833.50
# 482           315940.28       119643.91             53110.35         24977.35
# 483           282197.59       108580.52             40300.32         17426.58
# 484          1505922.75       158929.66             56203.88         27476.62
# 485           141185.05        11919.78              3982.18          5187.01
# 486           145724.31        13215.53              5065.80          2771.48
# 487           400928.22        49223.82             15553.23          5331.09
# 488           455875.62       107150.91             41093.60         18009.45
# 489           346996.00        51486.69             20034.21          8207.42
# 490           497921.03        61922.54             24523.50         11882.51
# 491           915384.88       142634.30             56197.17         28137.39
# 492           463835.31       177145.33             59561.05         18920.92
# 493           240976.73        63051.80             20045.37          5645.73
# 494           405508.97        51001.00             18703.86          9872.03
# 495           130142.86        14976.08              5975.55          3461.93
# 496           515996.47       102923.18             34908.77         17533.39
# 497           290036.53        67253.13             21707.56          8323.64
# 222            88015.74        14499.21              4044.85          2357.06
# 223            92338.09         6857.26              2489.52          1136.45
# 224           143727.00        36524.16             18762.59          7141.45
# 225           190715.36        25059.55              8489.58          5475.00
# 226           112243.86        53478.52             34739.53         29164.21
# 227            41420.09         6814.51              2920.60          2511.19
# 228           189578.92         1105.30               457.59           550.79
# 229            67187.77          788.26               268.02           174.08
# 230            97424.88        13461.86              5099.12          3259.08
# 231           104681.43        28483.60             14432.73         17581.43
# 232           782659.12       117979.94             37728.08         33636.11
# 233           139984.45        14049.40              5344.56          5301.90
#
#           4 - VeryHighRiskPop  5 - WaterBodyPop
# OBJECTID
# 1                   894089.81        1375101.75
# 1886                185655.78         158350.27
# 1887               3674224.50        1220584.00
# 1888               1154560.12         471537.50
# 1889               9616556.00         894555.31
# 1890               3464967.25        4432545.00
# 464                  18925.11             72.45
# 465                   4606.07              0.24
# 466                  15248.71              5.83
# 467                   8608.88            400.71
# 468                   4926.71              6.72
# 469                   1268.44              0.00
# 470                   8122.34             32.51
# 471                   1751.05           1614.10
# 472                   6743.18              0.00
# 473                   5329.96           1237.02
# 474                   8590.46              0.00
# 475                   4450.13            852.14
# 476                  53371.27              0.00
# 477                   1795.31             54.77
# 478                   9213.62              0.00
# 479                    319.05              0.00
# 480                   4270.32             26.70
# 481                  16661.60            109.54
# 482                  25322.36              8.86
# 483                   4778.30              0.00
# 484                  23605.06              0.00
# 485                   2747.44             62.64
# 486                   2779.48              0.00
# 487                    894.68              0.00
# 488                   4815.04              0.00
# 489                   3596.59              0.00
# 490                   4046.40              0.00
# 491                  27258.91              1.69
# 492                   4207.63              0.00
# 493                    534.72              0.00
# 494                   4283.11              0.00
# 495                   2513.20             18.38
# 496                   9799.55            668.88
# 497                   1845.23              1.96
# 222                   1595.82              0.35
# 223                   1314.05             43.47
# 224                   7172.38          66509.72
# 225                   4179.40          14883.81
# 226                  25672.12           1510.85
# 227                    603.09              1.68
# 228                    454.97           1857.72
# 229                     67.10              0.09
# 230                   2700.47             66.65
# 231                  23363.56           3834.86
# 232                  23016.96            182.91
# 233                   2396.83           3176.14

# %%
bad_countries = ['ADO', 'ABW', 'IDN', 'KAZ', 'KSV', 'MDV', 'MHL', 'VCT', 'WSM', 'SYC', 'TMP', 'TUV']

# %%
for shp_name, flood_name in matching_dict.items():  
    if flood_name == "not_found":
        print(f"{shp_name} does not have flood data")
    elif type(flood_name) == list:
        print(f"{shp_name} has multiple datasets, need to investigate")
    else:
        sub = adm.loc[adm['ADM0_NAME'] == shp_name].copy()
        # Create country polygon
        country = sub[['ADM0_NAME','geometry']] 
        country = country.dissolve(by='ADM0_NAME') 

        # Save country name
        countryCode = sub['CountryCod'].iloc[0]
        
        processedCountries = result['ISO3'].unique()
        if not countryCode in processedCountries and not countryCode in bad_countries:
            tPrint(f'{countryCode}: {sub.shape[0]}')        
            countryNameInfo = pycountry.countries.get(alpha_3=countryCode)
            ###################### Coastal Flood ######################

            # Get coastal flood
            cFloodRisk = rs.open(coastalFlood_path)

            # Mask to shapefile
            cFlood_masked, cFlood_affine = rs.mask.mask(dataset=cFloodRisk, shapes=country.geometry, crop=True)

            # Save results as raster
            ## Update the metadata
            out_meta = cFloodRisk.meta.copy()
            out_meta.update({"driver": "GTiff",
                              "height": cFlood_masked.shape[1], #check shapes
                              "width": cFlood_masked.shape[2],
                              "transform": cFlood_affine,
                             'count': 1})

            # Output file name
            coastalCroppedName = "coastalFlood_{}.tif".format(countryCode)

            ## export as a new geotiff 
            cFlood_outputfile = cFlood_outputFolderPath / coastalCroppedName
            with rs.open(cFlood_outputfile, 'w', **out_meta) as dest:
                dest.write(cFlood_masked)

            del cFlood_masked



            ###################### All Flood ######################

            # Get fluvial flood
            for name in flood_path.glob(flood_name):
                fluvialFlood_File = name / fluvialFlood_Folder / fluvialFlood_FileName
                fFloodRisk = rs.open(fluvialFlood_File)

            # Get pluvial flood
            for name in flood_path.glob(flood_name):
                pluvialFlood_File = name / pluvialFlood_Folder / pluvialFlood_FileName
                pFloodRisk = rs.open(pluvialFlood_File)

            # Get coastal flood
            cFloodRisk = rs.open(cFlood_outputfile)

            # Merge flood files. Using max pixel by pixel method
            floodArray, out_trans = merge([fFloodRisk, pFloodRisk, cFloodRisk], method='max')
            floodArray = floodArray.astype('float32') #reducing memory usage


            # Save results as raster
            ## Update the metadata
            out_meta = fFloodRisk.meta.copy()
            out_meta.update({"transform": out_trans})

            # Output file name
            floodName = "Flood_{}.tif".format(countryCode)

            ## export as a new geotiff 
            Flood_outputfile = Flood_outputFolderPath / floodName
            with rs.open(Flood_outputfile, 'w', **out_meta) as dest:
                dest.write(floodArray)

            # Calculate statistics 
            #print(stats(floodArray))
            # Convert to sparse array
            del floodArray


            ###################### Population ######################

            # Get population file
            ## Get alpha 3 code e.g. "VNM" and append glob search info
            countryAlpha3 = '*{}*'.format(countryCode) #countryNameInfo.alpha_3)
            for name in population_path.glob(countryAlpha3):
                pop_File = name

            pop = rs.open(pop_File)

            # Read as array
            popArray = pop.read()

            # Remove negatives
            popArray[popArray < 0] = 0

            # Calculate statistics 
            #print(stats(popArray))

            # Print population sum for country to compare against final results
            tPrint(f"{countryCode} Total Pop: {np.sum(popArray)}")

            ###################### Resample Flood ######################

            ## Resample file to pop file dimensions 
            with rs.open(Flood_outputfile) as dataset:
                flood_resampled = dataset.read(
                    out_shape=(
                        dataset.count,
                        int(pop.height), 
                        int(pop.width) 
                    ),
                    resampling=Resampling.bilinear
                )

            # Remove negatives
            flood_resampled[flood_resampled < 0] = 0

            # Reduce memory usage
            flood_resampled = flood_resampled.astype('float32') 

            # Adjust using transforms
            resample_ratio = pop.meta['transform'][0] / dataset.meta['transform'][0]
            ## ratio is 0.9999x so small adjustment
            flood_resampled = flood_resampled * resample_ratio

            # Calculate statistics 
            #print(stats(flood_resampled))


            ###################### Categorize by flood bins ######################

            # Categorizing
            floodCat = np.digitize(flood_resampled, flood_bins, right=True) # True to include right bin edge

            # Print freq dist to sense check results
            unique, counts = np.unique(floodCat, return_counts=True)
            dict(zip(unique, counts))

            del flood_resampled

            ###################### Convert to bool int arrays ######################

            # Create boolean int array for each risk category. 
            ## Create list of the number of categories 
            listNumberCat = range(numberCategories)

            ## Create empty list for the arrays
            list_IntBool_floodCat = []

            ## Create a boolean int array for each category
            for i in listNumberCat:
                intArray = (floodCat == i).astype(np.int)
                # Append array to list
                list_IntBool_floodCat.append(intArray)

            del floodCat
            del intArray

            ###################### Multiply flood array by pop array ######################

            # Multiply each int bool categorized flood array by the population array
            ## Create empty list for the arrays
            list_flood_pop = []

            ## Multiply the arrays and set dtype as float 32 to reduce memory 
            for i in range(len(list_IntBool_floodCat)):
                list_flood_pop.append(np.multiply(list_IntBool_floodCat[i], popArray).astype('float32'))

            #Create 3d array with all the arrays
            stack_flood_pop = (np.vstack((list_flood_pop)))

            # Delete variables that are no longer needed to free up memory
            del list_flood_pop
            del list_IntBool_floodCat

            # Calculate the total sum for each array  
            Flood_pop_sums = {
                '0 - NoRiskPop': np.sum(stack_flood_pop[0]),
                '1 - LowRiskPop': np.sum(stack_flood_pop[1]),
                '2 - ModerateRiskPop': np.sum(stack_flood_pop[2]),
                '3 - HighRiskPop': np.sum(stack_flood_pop[3]),
                '4 - VeryHighRiskPop': np.sum(stack_flood_pop[4]),
                '5 - WaterBodyPop': np.sum(stack_flood_pop[5])
            }
            #Flood_pop_sums

            ###################### Export flood pop raster ######################

            # Save results as raster
            ## Update the metadata
            Flood_Pop_out_meta = pop.meta.copy()
            Flood_Pop_out_meta.update({"nodata": 0.,
                                       'count': numberCategories})

            FloodPopName = "FloodPop_{}.tif".format(countryCode)

            ## export as a new geotiff 
            output_File = Raster_outputFolderPath / FloodPopName
            with rs.open(output_File, 'w', **Flood_Pop_out_meta) as dest:
                dest.write(stack_flood_pop)

            del stack_flood_pop


            ###################### Crop to Adm 1 ######################


            # Read raster back in to crop to adm1 polygons
            FloodPop = rs.open(output_File)


            # Crop raster to adm1 polygons, sum each layer, save results to df
            for namedTuple in sub.itertuples():
                # Mask country flood pop file using adm1 boundaries
                # Note: rasterio mask requires a multipolygon or a list of polygons
                # ... since some of the adm boundaries are polygons, 
                # ... then the shape has to put placed in a list e.g. [(polygon)]
                FloodPop_masked, FloodPop_affine =  rs.mask.mask(dataset=FloodPop, 
                                                              shapes=[(namedTuple[-1])], 
                                                              crop=True)
                # Calculate sum of each flood risk cat
                Flood_pop_sums_raster = {
                '0 - NoRiskPop': np.sum(FloodPop_masked[0]),
                '1 - LowRiskPop': np.sum(FloodPop_masked[1]),
                '2 - ModerateRiskPop': np.sum(FloodPop_masked[2]),
                '3 - HighRiskPop': np.sum(FloodPop_masked[3]),
                '4 - VeryHighRiskPop': np.sum(FloodPop_masked[4]),
                '5 - WaterBodyPop': np.sum(FloodPop_masked[5])
                }

                # Add sums to new cols in sub df
                for key,value in Flood_pop_sums_raster.items() :
                    sub.loc[namedTuple[0], key] = value

                #print('Row Index label : ', namedTuple[0]);

            # rounding the values to x decimal places
            decimals = 2
            sub.iloc[:,-6:] = sub.iloc[:,-6:].apply(lambda x: round(x, decimals));
            #sub


            ###################### Add to results df ######################

            # Keeping only the index and the new cols to make joining with the adm df easier
            sub = sub.iloc[:,-6:] 

            # This will be where the results are stored throughout the loop
            # "sub" is rewritten during each loop
            sub['ISO3'] = countryCode
            result = result.append(sub)
        else:
            tPrint(f'{countryCode} already processed')
# Out:
# 08:04:33	AFG already processed
# 08:04:33	ALB already processed
# Algeria does not have flood data
# American Samoa (U.S.) does not have flood data
# 08:04:33	ADO already processed
# 08:04:34	AGO already processed
# 08:04:34	ATG already processed
# Arab Republic of Egypt does not have flood data
# Argentina does not have flood data
# 08:04:34	ARM already processed
# 08:04:34	ABW already processed
# Australia does not have flood data
# Austria does not have flood data
# 08:04:34	AZE already processed
# Bahrain does not have flood data
# Bangladesh does not have flood data
# 08:04:34	BRB already processed
# 08:04:34	BLR already processed
# 08:04:34	BEL already processed
# 08:04:35	BLZ already processed
# 08:04:35	BEN already processed
# Bermuda (U.K.) does not have flood data
# 08:04:35	BTN already processed
# 08:04:36	BOL already processed
# 08:04:36	BIH already processed
# 08:04:36	BWA already processed
# Brazil does not have flood data
# 08:04:36	BRN already processed
# 08:04:36	BGR already processed
# 08:04:37	BFA already processed
# 08:04:37	BDI already processed
# 08:04:37	KHM already processed
# 08:04:37	CMR already processed
# Canada does not have flood data
# Cape Verde does not have flood data
# 08:04:37	CYM already processed
# 08:04:37	CAF already processed
# 08:04:37	TCD already processed
# Chile does not have flood data
# China does not have flood data
# 08:04:39	COL already processed
# 08:04:39	COM already processed
# 08:04:39	COG already processed
# 08:04:39	CRI already processed
# 08:04:39	HRV already processed
# 08:04:41	CUB already processed
# Curaçao (Neth.) does not have flood data
# 08:04:41	CYP already processed
# Czech Republic does not have flood data
# Côte d'Ivoire does not have flood data
# D. P. R. of Korea does not have flood data
# 08:04:42	COD already processed
# 08:04:42	DNK already processed
# 08:04:42	DJI already processed
# 08:04:42	DMA already processed
# 08:04:43	DOM already processed
# Ecuador does not have flood data
# 08:04:43	SLV already processed
# Equatorial Guinea does not have flood data
# 08:04:44	ERI already processed
# 08:04:53	EST already processed
# 08:04:53	ETH already processed
# 08:04:53	MKD already processed
# Faroe Islands (Den.) does not have flood data
# 08:04:53	FSM already processed
# Fiji has multiple datasets, need to investigate
# 08:04:54	FIN already processed
# France does not have flood data
# 08:04:54	PYF already processed
# 08:04:55	GAB already processed
# 08:04:55	GEO already processed
# 08:04:55	DEU already processed
# 08:04:56	GHA already processed
# 08:04:56	GRC already processed
# Greenland (Den.) does not have flood data
# 08:04:56	GRD already processed
# Guam (U.S.) does not have flood data
# 08:04:57	GTM already processed
# 08:04:58	GIN already processed
# 08:05:06	GNB already processed
# 08:05:06	GUY already processed
# 08:05:07	HTI already processed
# Honduras does not have flood data
# 08:05:07	HKG already processed
# 08:05:07	HUN already processed
# Iceland does not have flood data
# India does not have flood data
# 08:05:08	IDN already processed
# 08:05:08	IRQ already processed
# 08:05:08	IRL already processed
# Islamic Republic of Iran does not have flood data
# Isle of Man (U.K.) does not have flood data
# Israel does not have flood data
# Italy does not have flood data
# 08:05:08	JAM already processed
# 08:05:09	JPN already processed
# 08:05:09	JOR already processed
# 08:05:09	KAZ already processed
# 08:05:10	KEN already processed
# Kiribati does not have flood data
# 08:05:10	KSV already processed
# 08:05:10	KWT already processed
# 08:05:10	KGZ already processed
# 08:05:10	LAO already processed
# 08:05:10	LVA already processed
# 08:05:10	LBN already processed
# 08:05:10	LSO already processed
# 08:05:10	LBR already processed
# Libya does not have flood data
# Liechtenstein does not have flood data
# 08:05:10	LTU already processed
# 08:05:10	LUX already processed
# Macau, SAR does not have flood data
# 08:05:19	MDG already processed
# 08:05:20	MWI already processed
# 08:05:20	MYS already processed
# 08:05:20	MDV already processed
# 08:05:20	MLI already processed
# 08:05:20	MLT already processed
# 08:05:20	MHL already processed
# 08:05:21	MRT already processed
# 08:05:21	MUS already processed
# 08:05:35	MEX already processed
# 08:05:35	MDA already processed
# 08:05:35	MCO already processed
# 08:05:35	MNG already processed
# 08:05:35	MNE already processed
# Morocco does not have flood data
# 08:05:36	MOZ already processed
# 08:05:37	MMR already processed
# 08:05:38	NAM already processed
# 08:05:38	NPL already processed
# Netherlands does not have flood data
# 08:05:38	NCL already processed
# New Zealand does not have flood data
# 08:05:38	NIC already processed
# 08:05:39	NER already processed
# 08:05:39	NGA already processed
# Northern Mariana Islands (U.S.) does not have flood data
# 08:05:40	NOR already processed
# Oman does not have flood data
# 08:05:42	PAK already processed
# 08:05:42	PLW already processed
# 08:05:46	PAN already processed
# 08:05:46	PNG already processed
# 08:05:46	PRY already processed
# 08:05:47	PER already processed
# 08:05:48	PHL already processed
# 08:05:48	POL already processed
# 08:05:48	PRT already processed
# 08:05:49	PRI already processed
# Qatar does not have flood data
# R. B. de Venezuela does not have flood data
# Republic of Korea does not have flood data
# 08:05:49	YEM already processed
# 08:05:49	ROU already processed
# Russian Federation does not have flood data
# 08:05:50	RWA already processed
# Saint Kitts and Nevis does not have flood data
# 08:05:50	LCA already processed
# 08:05:50	VCT already processed
# Saint-Martin (Fr.) does not have flood data
# 08:05:50	WSM already processed
# 08:05:50	SMR already processed
# Saudi Arabia does not have flood data
# 08:05:52	SEN already processed
# 08:05:52	SRB already processed
# 08:05:52	SYC already processed
# Sierra Leone has multiple datasets, need to investigate
# 08:05:52	SGP already processed
# Sint Maarten (Neth.) does not have flood data
# Slovak Republic does not have flood data
# 08:05:52	SVN already processed
# 08:05:52	SLB already processed
# 08:05:53	SOM already processed
# 08:05:56	ZAF already processed
# South Sudan does not have flood data
# 08:05:58	ESP already processed
# 08:05:59	LKA already processed
# Sudan does not have flood data
# 08:05:59	SUR already processed
# Svalbard and Jan Mayen (Nor.) does not have flood data
# 08:05:59	SWZ already processed
# 08:06:00	SWE already processed
# Switzerland does not have flood data
# 08:06:00	SYR already processed
# São Tomé and Príncipe does not have flood data
# 08:06:00	TWN already processed
# 08:06:00	TJK already processed
# 08:06:03	TZA already processed
# 08:06:04	THA already processed
# 08:06:08	BHS already processed
# 08:06:08	GMB already processed
# 08:06:08	TMP already processed
# 08:06:09	TGO already processed
# 08:06:09	TON already processed
# 08:06:09	TTO already processed
# Tunisia does not have flood data
# 08:06:09	TUR already processed
# 08:06:09	TKM already processed
# 08:06:09	TCA already processed
# 08:06:09	TUV already processed
# 08:06:09	UGA: 4
# 08:06:16	UGA Total Pop: 42179480.0
# 08:06:31	UKR: 27
# 08:06:58	UKR Total Pop: 43794412.0
# United Arab Emirates does not have flood data
# 08:08:08	GBR: 12
# 08:08:32	GBR Total Pop: 67583272.0
# United States of America does not have flood data
# Uruguay does not have flood data
# Uzbekistan does not have flood data
# 08:09:20	VUT: 6
# 08:09:24	VUT Total Pop: 304070.09375
# 08:09:39	VNM: 6
# 08:09:55	VNM Total Pop: 99391680.0
# West Bank and Gaza does not have flood data
# 08:10:38	ZMB: 10
# 08:10:54	ZMB Total Pop: 18700106.0
# 08:11:49	ZWE: 1
# 08:11:57	ZWE Total Pop: 14360262.0

# %%
result
# Out:
#           0 - NoRiskPop  1 - LowRiskPop  2 - ModerateRiskPop  3 - HighRiskPop  \
# OBJECTID
# 464          1046078.50       116928.98             37952.16         20553.42
# 465           530143.12        79444.60             28575.88         13141.66
# 466           750063.06       125772.14             51365.71         26782.82
# 467          1027207.50       198866.39             53486.37         21337.35
# 468           430106.59        49097.92             17945.55          9337.93
# ...                 ...             ...                  ...              ...
# 139          2166785.75       917286.31            320666.44        112577.31
# 140           564034.69       335171.59             83222.23         44830.52
# 141          1281192.50       463698.94            174609.27         73495.13
# 142           399162.00       439853.62            123730.20         91195.42
# 1975         9992703.00      2870249.75            962031.94        389127.56
#
#           4 - VeryHighRiskPop  5 - WaterBodyPop ISO3
# OBJECTID
# 464                  18925.11             72.45  AFG
# 465                   4606.07              0.24  AFG
# 466                  15248.71              5.83  AFG
# 467                   8608.88            400.71  AFG
# 468                   4926.71              6.72  AFG
# ...                       ...               ...  ...
# 139                  30529.88            401.19  ZMB
# 140                  23883.65             38.62  ZMB
# 141                  65096.73         112834.66  ZMB
# 142                  49316.59           1110.08  ZMB
# 1975                137893.97           8153.18  ZWE
#
# [1186 rows x 7 columns]

# %%
# To create a merged df with only rows that have results:
mergedDf = adm.merge(result, how='left', left_index=True, right_index=True)
mergedDf.to_file(os.path.join(outputPath, "processed_countries.shp"))

# To create a merged df with all original rows, including ones without results:
mergedDf = adm.merge(result, left_index=True, right_index=True)
mergedDf.to_file(os.path.join(outputPath, "all_countries.shp"))
# Out:
# WARNING:fiona._env:Normalized/laundered field name: '0 - NoRiskPop' to '0 - NoRisk'
# WARNING:fiona._env:Normalized/laundered field name: '1 - LowRiskPop' to '1 - LowRis'
# WARNING:fiona._env:Normalized/laundered field name: '2 - ModerateRiskPop' to '2 - Modera'
# WARNING:fiona._env:Normalized/laundered field name: '3 - HighRiskPop' to '3 - HighRi'
# WARNING:fiona._env:Normalized/laundered field name: '4 - VeryHighRiskPop' to '4 - VeryHi'
# WARNING:fiona._env:Normalized/laundered field name: '5 - WaterBodyPop' to '5 - WaterB'
# WARNING:fiona._env:Normalized/laundered field name: '0 - NoRiskPop' to '0 - NoRisk'
# WARNING:fiona._env:Normalized/laundered field name: '1 - LowRiskPop' to '1 - LowRis'
# WARNING:fiona._env:Normalized/laundered field name: '2 - ModerateRiskPop' to '2 - Modera'
# WARNING:fiona._env:Normalized/laundered field name: '3 - HighRiskPop' to '3 - HighRi'
# WARNING:fiona._env:Normalized/laundered field name: '4 - VeryHighRiskPop' to '4 - VeryHi'
# WARNING:fiona._env:Normalized/laundered field name: '5 - WaterBodyPop' to '5 - WaterB'

# %%
result['ISO3'].unique()
# Out:
# array(['AFG', 'ALB', 'AGO', 'ATG', 'ARM', 'AZE', 'BRB', 'BLR', 'BEL',
#        'BLZ', 'BEN', 'BTN', 'BOL', 'BIH', 'BWA', 'BRN', 'BGR', 'BFA',
#        'BDI', 'KHM', 'CMR', 'CYM', 'CAF', 'TCD', 'COL', 'COM', 'COG',
#        'CRI', 'HRV', 'CUB', 'CYP', 'COD', 'DNK', 'DJI', 'DMA', 'DOM',
#        'SLV', 'ERI', 'EST', 'ETH', 'MKD', 'FSM', 'FIN', 'PYF', 'GAB',
#        'GEO', 'DEU', 'GHA', 'GRC', 'GRD', 'GTM', 'GIN', 'GNB', 'GUY',
#        'HTI', 'HKG', 'HUN', 'IRQ', 'IRL', 'JAM', 'JPN', 'JOR', 'KEN',
#        'KWT', 'KGZ', 'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LTU', 'LUX',
#        'MDG', 'MWI', 'MYS', 'MLI', 'MLT', 'MRT', 'MUS', 'MEX', 'MDA',
#        'MCO', 'MNG', 'MNE', 'MOZ', 'MMR', 'NAM', 'NPL', 'NCL', 'NIC',
#        'NER', 'NGA', 'NOR', 'PAK', 'PLW', 'PAN', 'PNG', 'PRY', 'PER',
#        'PHL', 'POL', 'PRT', 'PRI', 'YEM', 'ROU', 'RWA', 'LCA', 'SMR',
#        'SEN', 'SRB', 'SGP', 'SVN', 'SLB', 'SOM', 'ZAF', 'ESP', 'LKA',
#        'SUR', 'SWZ', 'SWE', 'SYR', 'TWN', 'TJK', 'TZA', 'THA', 'BHS',
#        'GMB', 'TGO', 'TON', 'TTO', 'TUR', 'TKM', 'TCA', 'UGA', 'UKR',
#        'GBR', 'VUT', 'VNM', 'ZMB', 'ZWE'], dtype=object)
